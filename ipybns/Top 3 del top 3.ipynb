# %%
import numpy as np
import pandas as pd

# %%
perfil_afinidad = pd.read_csv('../csvs/perfil_afinidad_celulas_29, Obtener perfiles de afinidad.csv')
perfil_afinidad['id_compuestos_actividad'] = perfil_afinidad['id_compuestos_actividad'].str.replace("[","")
perfil_afinidad['id_compuestos_actividad'] = perfil_afinidad['id_compuestos_actividad'].str.replace("]","")
perfil_afinidad
# Out:
# C:\Users\Reyum\AppData\Local\Temp\ipykernel_8144\2518517562.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   perfil_afinidad['id_compuestos_actividad'] = perfil_afinidad['id_compuestos_actividad'].str.replace("[","")
# C:\Users\Reyum\AppData\Local\Temp\ipykernel_8144\2518517562.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   perfil_afinidad['id_compuestos_actividad'] = perfil_afinidad['id_compuestos_actividad'].str.replace("]","")
#       cell_id                            id_compuestos_actividad
# 0           1                 2580, 5105, 13590, 178357, 1148287
# 1           2                             42503, 444713, 1337017
# ...

# %%
top3 = pd.read_csv('../csvs/top3_with_smiles, fix_top3.csv')
top3['top3'] = top3['top3'].str.replace("[","")
top3['top3'] = top3['top3'].str.replace("]","")
top3
# Out:
# C:\Users\Reyum\AppData\Local\Temp\ipykernel_8144\944545554.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top3['top3'] = top3['top3'].str.replace("[","")
# C:\Users\Reyum\AppData\Local\Temp\ipykernel_8144\944545554.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top3['top3'] = top3['top3'].str.replace("]","")
#      comp_id                 top3    id_29     pref_name  \
# 0         30      11852, 1025, 41      789    METOPROLOL
# 1         35                          1022     ARECOLINE
# 2         37     732, 1969, 12063     1216  TRIMETHOPRIM
# 3         43       253, 9820, 195     1370   PROPRANOLOL
# 4         74    423, 16216, 16217     2214     SEROTONIN
# ...

# %%
[top3['top3']]
# Out:
# [0          11852, 1025, 41
#  1
#  2         732, 1969, 12063
#  3           253, 9820, 195
#  4        423, 16216, 16217
#                ...
#  133      38361, 2954, 2982
#  134
#  135       3001, 3002, 3000
#  136    46954, 46962, 15475
#  137    46948, 46953, 46956
#  Name: top3, Length: 138, dtype: object]

# %%
for i in range(top3['comp_id'].size):
#     print(top3.iloc[i]['comp_id'])
    op = top3.iloc[i][top3.columns[1].split(', ')]
    op = op[0].split(', ')
    for i in op:
        var = top3[top3['comp_id'] == i]
        print(var)

# op = top3.iloc[4][top3.columns[1].split(', ')]
# op = op[0].split(', ')
# print(op)
# for i in op:
#     var = top3[top3['comp_id'] == 35]
#     print(var)
# Out:
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []
# ...

# %%
perfil_afinidad.iloc[2][perfil_afinidad.columns[1]]
for i in range(perfil_afinidad['cell_id'].size):
    print (perfil_afinidad.iloc[i])
# perfil_afinidad[perfil_afinidad.columns[2]]
# perfil_afinidad[perfil_afinidad.columns[2]]
# Out:
# cell_id                                                     1
# id_compuestos_actividad    2580, 5105, 13590, 178357, 1148287
# Name: 0, dtype: object
# cell_id                                         2
# id_compuestos_actividad    42503, 444713, 1337017
# Name: 1, dtype: object
# cell_id                                                                    3
# id_compuestos_actividad    5769, 16758, 16949, 103459, 287231, 446279, 23...
# Name: 2, dtype: object
# cell_id                                                                    5
# id_compuestos_actividad    717, 2208, 5105, 5268, 8633, 11305, 13590, 499...
# Name: 3, dtype: object
# cell_id                                          7
# id_compuestos_actividad    68607, 1704201, 1704202
# Name: 4, dtype: object
# cell_id                         9
# id_compuestos_actividad    399526
# Name: 5, dtype: object
# cell_id                       10
# id_compuestos_actividad    29831
# Name: 6, dtype: object
# ...

# %%
#789 in perfil_afinidad['id_compuestos_actividad']
top3[top3['id_29']==5268]
# Out:
# Empty DataFrame
# Columns: [comp_id, top3, id_29, pref_name, smiles]
# Index: []

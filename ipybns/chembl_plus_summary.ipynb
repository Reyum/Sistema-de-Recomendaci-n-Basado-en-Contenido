# %%
import pandas as pd
import numpy as np
import csv

# %%
b_summary = pd.read_csv('../csvs/b_summary_29, Obtener_BSummary.csv', index_col=0)
b_summary = b_summary.sort_values('cell_id')
b_summary['compound_id'].unique().size
# Out:
# 22518

# %%
chembl_29 = pd.read_csv('../csvs/chembl29_drugs.csv', index_col=0)
chembl_29
# Out:
#                molregno chembl-name  \
# chembl_id
# CHEMBL6329            1         NaN
# CHEMBL6328            2         NaN
# CHEMBL265667          3         NaN
# CHEMBL6362            4         NaN
# CHEMBL267864          5         NaN
# ...                 ...         ...
# CHEMBL4651250   2487510         NaN
# CHEMBL4651251   2487511         NaN
# CHEMBL4651252   2487512         NaN
# CHEMBL4651253   2487513         NaN
# CHEMBL4651254   2487514         NaN
#
#                                                           smiles
# chembl_id
# CHEMBL6329          Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccccc1Cl
# CHEMBL6328       Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(C#N)cc1
# CHEMBL265667    Cc1cc(-n2ncc(=O)[nH]c2=O)cc(C)c1C(O)c1ccc(Cl)cc1
# CHEMBL6362          Cc1ccc(C(=O)c2ccc(-n3ncc(=O)[nH]c3=O)cc2)cc1
# CHEMBL267864      Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(Cl)cc1
# ...                                                          ...
# ...

# %%
chembl_30 = pd.read_csv('../csvs/chembl30_drugs.csv', index_col=0)
chembl_30
# Out:
#                molregno        chembl-name  \
# chembl_id
# CHEMBL6329            1                NaN
# CHEMBL6328            2                NaN
# CHEMBL265667          3                NaN
# CHEMBL6362            4                NaN
# CHEMBL267864          5                NaN
# ...                 ...                ...
# CHEMBL4804168   2539419                NaN
# CHEMBL4804169   2539420                NaN
# CHEMBL4804170   2539421                NaN
# CHEMBL4804171   2539422  AFP-464 FREE SALT
# CHEMBL4804173   2539424       FLORQUINITAU
#
#                                                           smiles
# chembl_id
# CHEMBL6329          Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccccc1Cl
# CHEMBL6328       Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(C#N)cc1
# CHEMBL265667    Cc1cc(-n2ncc(=O)[nH]c2=O)cc(C)c1C(O)c1ccc(Cl)cc1
# CHEMBL6362          Cc1ccc(C(=O)c2ccc(-n3ncc(=O)[nH]c3=O)cc2)cc1
# CHEMBL267864      Cc1cc(-n2ncc(=O)[nH]c2=O)ccc1C(=O)c1ccc(Cl)cc1
# ...

# %%
chembl[chembl['molregno'] == 789]
# Out:
#            molregno chembl-name                       smiles
# chembl_id
# CHEMBL13        789  METOPROLOL  COCCc1ccc(OCC(O)CNC(C)C)cc1

# %%
compound_array = b_summary['compound_id'].unique()
compound_array
# Out:
# array([     97,     148,     173, ..., 2486460, 2486462, 2486465],
#       dtype=int64)

# %%
csv_chembl29_summary = chembl[chembl['molregno'].isin(compound_array)]

# %%
csv_chembl29_summary
# Out:
#                molregno             chembl-name  \
# chembl_id
# CHEMBL2              97                PRAZOSIN
# CHEMBL6246          148            ELLAGIC ACID
# CHEMBL6             173            INDOMETHACIN
# CHEMBL6291          213  BISINDOLYLMALEIMIDE IX
# CHEMBL10            250               SB-203580
# ...                 ...                     ...
# CHEMBL4649860   2486411                     NaN
# CHEMBL4649905   2486456                     NaN
# CHEMBL4649909   2486460                     NaN
# CHEMBL4649911   2486462                     NaN
# CHEMBL4649914   2486465                     NaN
#
#                                                           smiles
# chembl_id
# CHEMBL2            COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# CHEMBL6246            O=c1oc2c(O)c(O)cc3c(=O)oc4c(O)c(O)cc1c4c23
# CHEMBL6           COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
# CHEMBL6291     Cn1cc(C2=C(c3cn(CCCSC(=N)N)c4ccccc34)C(=O)NC2=...
# ...

# %%
b_summary.to_csv('../csvs/csv_chembl29_summaryV2, chembl_plus_summary.csv', index = False)

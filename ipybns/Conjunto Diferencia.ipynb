# %%
import numpy as np
import pandas as pd

# %%
summ_29 = pd.read_csv('../csvs/summary29.csv', index_col = 0)
summ_29
# Out:
#          compound_id  cell_id  active
# 0                556      163      -1
# 1              82983      163      -1
# 2            1633207      163      -1
# 3            1633675      163      -1
# 4              47675      163      -1
# ...              ...      ...     ...
# 5590420      1570918      489      -1
# 5590421      2484913      440      -1
# 5590422      2484913      649      -1
# 5590423      2484913      559      -1
# 5590424      2475686      440      -1
#
# [3594943 rows x 3 columns]

# %%
summ_30 = pd.read_csv('../csvs/act_summary30.csv', index_col = 0)
summ_30
# Out:
#          compound_id  cell_id  active
# 0                556      163      -1
# 1              82983      163      -1
# 2            1633207      163      -1
# 3            1633675      163      -1
# 4              47675      163      -1
# ...              ...      ...     ...
# 5987118      2531656      594      -1
# 5987119      2531656     1213      -1
# 5987120      2537326     1213      -1
# 5987121      2531656      630      -1
# 5987122      2531656      491      -1
#
# [3359808 rows x 3 columns]

# %%
num_nuevos_compuestos = summ_30['compound_id'].unique().size - summ_29['compound_id'].unique().size
num_nuevos_compuestos #11853
# Out:
# 11853

# %%
compuestos_29 = summ_29['compound_id'].unique()
compuestos_29 = compuestos_29.tolist() #numpy.ndarray
#len (compuestos_29) #446635
compuestos_29
# Out:
# [556,
#  82983,
#  1633207,
#  1633675,
#  47675,
#  1633268,
#  1633652,
#  286631,
#  49931,
#  1633750,
#  1633752,
#  1633753,
#  1633749,
#  83026,
#  83027,
#  1633754,
#  1633746,
#  1633751,
#  1633748,
#  1633747,
#  82982,
#  69954,
#  699563,
#  68845,
#  69711,
#  69448,
#  69987,
#  69986,
#  69712,
#  1633264,
#  1633676,
#  1633206,
#  73598,
#  157810,
#  14440,
#  157844,
#  63363,
#  193386,
#  546837,
#  194395,
#  22949,
#  193680,
#  23564,
#  546840,
#  193873,
#  193414,
#  193835,
#  193182,
#  193874,
#  162809,
#  162861,
#  162896,
#  162840,
#  162860,
#  31543,
#  256640,
#  256084,
#  433092,
#  256073,
#  256116,
#  1383647,
#  1383648,
#  1383649,
#  519602,
#  256179,
#  256504,
#  256599,
#  255760,
#  255804,
#  256180,
#  256137,
#  256639,
#  256506,
#  122480,
#  66675,
#  67196,
#  62237,
#  30058,
#  390877,
#  210170,
#  33986,
#  209849,
#  251562,
#  251595,
#  251473,
#  252049,
#  251627,
#  251628,
#  251630,
#  251153,
#  251154,
# ...

# %%
compuestos_30 = summ_30['compound_id'].unique()
compuestos_30 = compuestos_30.tolist()
#len (compuestos_30) #458488
compuestos_30
# Out:
# [556,
#  82983,
#  1633207,
#  1633675,
#  47675,
#  1633268,
#  1633652,
#  286631,
#  49931,
#  1633750,
#  1633752,
#  1633753,
#  1633749,
#  83026,
#  83027,
#  1633754,
#  1633746,
#  1633751,
#  1633748,
#  1633747,
#  82982,
#  69954,
#  699563,
#  68845,
#  69711,
#  69448,
#  69987,
#  69986,
#  69712,
#  1633264,
#  1633676,
#  1633206,
#  73598,
#  157810,
#  14440,
#  157844,
#  63363,
#  546837,
#  194395,
#  22949,
#  193680,
#  23564,
#  546840,
#  193873,
#  193414,
#  193835,
#  193182,
#  193874,
#  162809,
#  162861,
#  162896,
#  162840,
#  162860,
#  31543,
#  256640,
#  256084,
#  433092,
#  256073,
#  256116,
#  1383647,
#  1383648,
#  1383649,
#  519602,
#  256179,
#  256504,
#  256599,
#  255760,
#  255804,
#  256180,
#  256137,
#  256639,
#  256506,
#  122480,
#  66675,
#  67196,
#  62237,
#  30058,
#  390877,
#  210170,
#  209849,
#  209873,
#  209885,
#  251562,
#  251595,
#  251473,
#  251627,
#  251628,
#  251154,
#  251592,
#  251472,
#  251594,
# ...

# %%
cont = 0
lista_diferencia_compuestos = []
for i in compuestos_30:
    if i not in compuestos_29:
        lista_diferencia_compuestos.append(i)
lista_diferencia_compuestos.sort()

# %%
len(lista_diferencia_compuestos)
# Out:
# 22107

# %%
if summ_29[summ_29['compound_id'] == 205]:
    print("si hay")
else:
    print("no")
#205 in summ_29['compound_id']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <module>
# ----> 1 if summ_29[summ_29['compound_id'] == 205]:
#       2     print("si hay")
#       3 else:
#
# File D:\Programas\Anaconda\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
cont = 0
lista_diferencia_compuestos_2 = []
for i in summ_30['compound_id'].unique():
    if i not in summ_29['compound_id']:
        lista_diferencia_compuestos_2.append(summ_30[summ_30['compound_id'] == i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <module>
#       4     if i not in summ_29['compound_id']:
#       5         lista_diferencia_compuestos_2.append(summ_30[summ_30['compound_id'] == i])
# ----> 6 lista_diferencia_compuestos_2.sort()
#
# File D:\Programas\Anaconda\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File D:\Programas\Anaconda\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# ...

# %%
lista_diferencia_compuestos_2
# Out:
# [        compound_id  cell_id  active
#  0               556      163      -1
#  58961           556      570      -1
#  101269          556      907      -1
#  101294          556      895      -1,
#           compound_id  cell_id  active
#  1              82983      163      -1
#  949            82983      723      -1
#  8709           82983      972      -1
#  10893          82983      646      -1
#  16238          82983      988      -1
#  ...              ...      ...     ...
#  5276342        82983      281      -1
#  5283354        82983      583      -1
#  5651745        82983     5673      -1
#  5660540        82983      605      -1
#  5660550        82983      694      -1
#
#  [120 rows x 3 columns],
#           compound_id  cell_id  active
#  4              47675      163      -1
#  58956          47675      570       1
#  120702         47675      692      -1
#  300000         47675      502      -1
#  435165         47675      496      -1
# ...
